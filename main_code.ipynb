# %%
from dotenv import load_dotenv
import os

load_dotenv()
openai_key = os.getenv("openai_api_key")

# %% [markdown]
# # Creating the data!!

# %%
import os
import requests
import pandas as pd

filepath1 = '/Users/emmyson/InsightCoffee/AllCoffeeFinalApril.csv'
cafe_df = pd.read_csv(filepath1, header = 0)

# %%
# updated 2019
cafe_df.head()
# Out:
#    Unnamed: 0                                     alias  \
# 0           0            taliza-coffee-santa-fe-springs
# 1           1                    kape-republik-cerritos
# 2           2                   7-leaves-cafe-artesia-3
# 3           3                         cafe-maji-artesia
# 4           4  perfected-quality-coffee-service-norwalk
#
#                                           categories  \
# 0  ['coffeeroasteries', 'coffee', 'breakfast_brun...
# 1                    ['desserts', 'cafes', 'coffee']
# 2                             ['coffee', 'macarons']
# 3                     ['cafes', 'coffee', 'burgers']
# 4                                         ['coffee']
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 33.9029363647326, 'longitude': -1...  (213) 330-5229
# 1  {'latitude': 33.8739356994629, 'longitude': -1...  (562) 865-5000
# 2  {'latitude': 33.8727839736181, 'longitude': -1...  (562) 278-2572
# 3  {'latitude': 33.8729251, 'longitude': -118.071...  (562) 281-9511
# 4    {'latitude': 33.89087, 'longitude': -118.06323}  (562) 921-7470
#
#       distance                      id  \
# 0  1737.700260  rs5eKXExQrwSvUJNi0A78g
# 1  2029.428768  eDTipq688TIhMTkDMhdaUA
# 2  2258.545948  mAhkHjXLddbmxftSTz_OEw
# 3  2187.379592  YhJ2bXYk-SIxpFfT4RgHUQ
# 4   546.043077  934ULxIbOV7NcuTjHrkfQw
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/LCyCTi...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/X7nAJn...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/L2yyn2...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/rmNuVr...      False
# 4                                                NaN      False
#
#                                             location  \
# 0  {'address1': '13217 Rosecrans Ave', 'address2'...
# 1  {'address1': '17206 Norwalk Blvd', 'address2':...
# 2  {'address1': '12154 Artesia Blvd', 'address2':...
# 3  {'address1': '12232 E Artesia Blvd', 'address2...
# 4  {'address1': '15416 Lancelot Ave', 'address2':...
#
#                                name         phone price  rating  review_count  \
# 0                     Taliza Coffee  1.213331e+10     $     4.5           132
# 1                     Kape Republik  1.562866e+10     $     4.5           582
# 2                     7 Leaves Cafe  1.562278e+10     $     4.0           379
# 3                         Cafe Maji  1.562282e+10     $     4.0           963
# 4  Perfected Quality Coffee Service  1.562922e+10   NaN     5.0             1
#
#              transactions                                                url  \
# 0                      []  https://www.yelp.com/biz/taliza-coffee-santa-f...
# 1  ['delivery', 'pickup']  https://www.yelp.com/biz/kape-republik-cerrito...
# 2                      []  https://www.yelp.com/biz/7-leaves-cafe-artesia...
# 3                      []  https://www.yelp.com/biz/cafe-maji-artesia?adj...
# 4                      []  https://www.yelp.com/biz/perfected-quality-cof...
#
#          long        lat
# 0 -118.049800  33.902936
# 1 -118.071419  33.873936
# 2 -118.072899  33.872784
# 3 -118.071635  33.872925
# 4 -118.063230  33.890870

# %%
cafe_df.drop(columns = ['Unnamed: 0'], axis = 1, inplace = True)
cafe_df.head()
# Out:
#                                       alias  \
# 0            taliza-coffee-santa-fe-springs
# 1                    kape-republik-cerritos
# 2                   7-leaves-cafe-artesia-3
# 3                         cafe-maji-artesia
# 4  perfected-quality-coffee-service-norwalk
#
#                                           categories  \
# 0  ['coffeeroasteries', 'coffee', 'breakfast_brun...
# 1                    ['desserts', 'cafes', 'coffee']
# 2                             ['coffee', 'macarons']
# 3                     ['cafes', 'coffee', 'burgers']
# 4                                         ['coffee']
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 33.9029363647326, 'longitude': -1...  (213) 330-5229
# 1  {'latitude': 33.8739356994629, 'longitude': -1...  (562) 865-5000
# 2  {'latitude': 33.8727839736181, 'longitude': -1...  (562) 278-2572
# 3  {'latitude': 33.8729251, 'longitude': -118.071...  (562) 281-9511
# 4    {'latitude': 33.89087, 'longitude': -118.06323}  (562) 921-7470
#
#       distance                      id  \
# 0  1737.700260  rs5eKXExQrwSvUJNi0A78g
# 1  2029.428768  eDTipq688TIhMTkDMhdaUA
# 2  2258.545948  mAhkHjXLddbmxftSTz_OEw
# 3  2187.379592  YhJ2bXYk-SIxpFfT4RgHUQ
# 4   546.043077  934ULxIbOV7NcuTjHrkfQw
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/LCyCTi...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/X7nAJn...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/L2yyn2...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/rmNuVr...      False
# 4                                                NaN      False
#
#                                             location  \
# 0  {'address1': '13217 Rosecrans Ave', 'address2'...
# 1  {'address1': '17206 Norwalk Blvd', 'address2':...
# 2  {'address1': '12154 Artesia Blvd', 'address2':...
# 3  {'address1': '12232 E Artesia Blvd', 'address2...
# 4  {'address1': '15416 Lancelot Ave', 'address2':...
#
#                                name         phone price  rating  review_count  \
# 0                     Taliza Coffee  1.213331e+10     $     4.5           132
# 1                     Kape Republik  1.562866e+10     $     4.5           582
# 2                     7 Leaves Cafe  1.562278e+10     $     4.0           379
# 3                         Cafe Maji  1.562282e+10     $     4.0           963
# 4  Perfected Quality Coffee Service  1.562922e+10   NaN     5.0             1
#
#              transactions                                                url  \
# 0                      []  https://www.yelp.com/biz/taliza-coffee-santa-f...
# 1  ['delivery', 'pickup']  https://www.yelp.com/biz/kape-republik-cerrito...
# 2                      []  https://www.yelp.com/biz/7-leaves-cafe-artesia...
# 3                      []  https://www.yelp.com/biz/cafe-maji-artesia?adj...
# 4                      []  https://www.yelp.com/biz/perfected-quality-cof...
#
#          long        lat
# 0 -118.049800  33.902936
# 1 -118.071419  33.873936
# 2 -118.072899  33.872784
# 3 -118.071635  33.872925
# 4 -118.063230  33.890870

# %%
# create a function to combine text for embedding
def combine_text(row):
    name = row['name'] if 'name' in row else ''
    categories = ', '.join(row['categories']) if isinstance(row['categories'], list) else ''
    location = row['location'] if isinstance(row['location'], dict) else {}
    address_parts = [
        location.get('address1', ''),
        location.get('city', ''),
        location.get('state', ''),
        location.get('zip_code', '')
    ]
    address = ', '.join([part for part in address_parts if part])
    price = row['price'] if 'price' in row else ''
    rating = str(row['rating']) if 'rating' in row else ''
    review_count = str(row['review_count']) if 'review_count' in row else ''

    return f"{name}. Categories: {categories}. Location: {address}. Price: {price}. Rating: {rating}/5 from {review_count} reviews."

# %%
# apply the function to create a new column for embeddings
cafe_df['embedding_text'] = cafe_df.apply(combine_text, axis=1)
cafe_df.head()
# Out:
#                                       alias  \
# 0            taliza-coffee-santa-fe-springs
# 1                    kape-republik-cerritos
# 2                   7-leaves-cafe-artesia-3
# 3                         cafe-maji-artesia
# 4  perfected-quality-coffee-service-norwalk
#
#                                           categories  \
# 0  ['coffeeroasteries', 'coffee', 'breakfast_brun...
# 1                    ['desserts', 'cafes', 'coffee']
# 2                             ['coffee', 'macarons']
# 3                     ['cafes', 'coffee', 'burgers']
# 4                                         ['coffee']
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 33.9029363647326, 'longitude': -1...  (213) 330-5229
# 1  {'latitude': 33.8739356994629, 'longitude': -1...  (562) 865-5000
# 2  {'latitude': 33.8727839736181, 'longitude': -1...  (562) 278-2572
# 3  {'latitude': 33.8729251, 'longitude': -118.071...  (562) 281-9511
# 4    {'latitude': 33.89087, 'longitude': -118.06323}  (562) 921-7470
#
#       distance                      id  \
# 0  1737.700260  rs5eKXExQrwSvUJNi0A78g
# 1  2029.428768  eDTipq688TIhMTkDMhdaUA
# 2  2258.545948  mAhkHjXLddbmxftSTz_OEw
# 3  2187.379592  YhJ2bXYk-SIxpFfT4RgHUQ
# 4   546.043077  934ULxIbOV7NcuTjHrkfQw
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/LCyCTi...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/X7nAJn...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/L2yyn2...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/rmNuVr...      False
# 4                                                NaN      False
#
#                                             location  \
# 0  {'address1': '13217 Rosecrans Ave', 'address2'...
# 1  {'address1': '17206 Norwalk Blvd', 'address2':...
# 2  {'address1': '12154 Artesia Blvd', 'address2':...
# 3  {'address1': '12232 E Artesia Blvd', 'address2...
# 4  {'address1': '15416 Lancelot Ave', 'address2':...
#
#                                name         phone price  rating  review_count  \
# 0                     Taliza Coffee  1.213331e+10     $     4.5           132
# 1                     Kape Republik  1.562866e+10     $     4.5           582
# 2                     7 Leaves Cafe  1.562278e+10     $     4.0           379
# 3                         Cafe Maji  1.562282e+10     $     4.0           963
# 4  Perfected Quality Coffee Service  1.562922e+10   NaN     5.0             1
#
#              transactions                                                url  \
# 0                      []  https://www.yelp.com/biz/taliza-coffee-santa-f...
# 1  ['delivery', 'pickup']  https://www.yelp.com/biz/kape-republik-cerrito...
# 2                      []  https://www.yelp.com/biz/7-leaves-cafe-artesia...
# 3                      []  https://www.yelp.com/biz/cafe-maji-artesia?adj...
# 4                      []  https://www.yelp.com/biz/perfected-quality-cof...
#
#          long        lat                                     embedding_text
# 0 -118.049800  33.902936  Taliza Coffee. Categories: . Location: . Price...
# 1 -118.071419  33.873936  Kape Republik. Categories: . Location: . Price...
# 2 -118.072899  33.872784  7 Leaves Cafe. Categories: . Location: . Price...
# 3 -118.071635  33.872925  Cafe Maji. Categories: . Location: . Price: $....
# 4 -118.063230  33.890870  Perfected Quality Coffee Service. Categories: ...

# %%
# function to get address string from location dictionary
def get_address_string(row):
    location = row['location'] if isinstance(row['location'], dict) else {}
    return ', '.join([location.get('address1', ''), location.get('city', ''), location.get('state', '')])

# %%
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
import pandas as pd
from langchain_openai import ChatOpenAI

docs = [
    Document(
        page_content=row['embedding_text'],
        metadata={
            "name": row.get("name", ""),
            "address": get_address_string(row)
        }
    )
    for _, row in cafe_df.iterrows()
]

embedding_function = OpenAIEmbeddings(api_key=openai_key, model="text-embedding-3-small")

vectorstore = Chroma.from_documents(
    docs,
    embedding=embedding_function,
    persist_directory="chroma_db"
)

retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3}
)

prompt_message = """
Find me cafe suggestions based on the following preferences:

Preferences:
{preferences}

Top Cafes:
"""

prompt_template = ChatPromptTemplate.from_messages([
    ("human", prompt_message)
])

llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    api_key=openai_key,
    temperature=1.0
)

rag_chain = (
    {"preferences": retriever, "input": RunnablePassthrough()}
    | prompt_template
    | llm
)
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
query = "I want a modern korean cafe with matcha, coffee, and wifi in Montclair. I prefer cafes with plenty of seating for studying. Show me the top 3 cafes that match my preferences, including their names, locations, and a brief description of their offerings."
response = rag_chain.invoke(query)

print(response.content)
# Out:
# Based on your preferences, here are some cafe suggestions that include "The Coffee Bean & Tea Leaf" locations:
#
# 1. **The Coffee Bean & Tea Leaf**
#    - **Location:** 8328 Wilshire Blvd, Beverly Hills, CA 90211
#    - **Rating:** 3.0/5 from 70 reviews
#    - **Price Range:** $
#    - **Description:** A popular spot known for its variety of coffee and tea options.
#
# 2. **The Coffee Bean & Tea Leaf**
#    - **Location:** 1500 Canada Blvd, Unit C, Glendale, CA 91208
#    - **Rating:** 3.0/5 from 70 reviews
#    - **Price Range:** $
#    - **Description:** Another location of the well-known chain, offering a similar selection of beverages in a casual environment.
#
# Both locations offer a consistent brand experience and are well-rated among patrons. If you're looking for more diverse options or different cafe types, feel free to specify!
